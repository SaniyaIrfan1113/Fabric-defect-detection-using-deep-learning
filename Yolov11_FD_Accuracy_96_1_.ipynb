# %% [markdown]
# <a href="https://colab.research.google.com/github/SaniyaIrfan1113/Fabric-defect-detection-using-deep-learning/blob/main/Yolov11_FD_Accuracy_96_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Feb 28 07:04:55 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install "ultralytics<=8.3.40" supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 35.7/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pilo1phCa5MQHOOzhDzc")
project = rf.workspace("saniya-irfan-vtnss").project("my-first-project-7oq45")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-1 in yolov11:: 100%|██████████| 3532/3532 [00:00<00:00, 5307.95it/s]

# %%
# !yolo train model=yolo11n.pt data=/content/My-First-Project-1/data.yaml epochs=80 imgsz=640
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 323MB/s]
# New https://pypi.org/project/ultralytics/8.3.80 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/confusion_matrix.png'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/confusion_matrix_normalized.png'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/F1_curve.png'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/PR_curve.png'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/P_curve.png'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/R_curve.png'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/results.png'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/train_batch2.jpg'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/runs/detect/train/val_batch1_labels.jpg'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
# Pip install from source
# !pip install git+https://github.com/ultralytics/ultralytics@main
# Out:
# ...
#   Cloning https://github.com/ultralytics/ultralytics (to revision main) to /tmp/pip-req-build-dx0o7yi8
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/ultralytics /tmp/pip-req-build-dx0o7yi8
#   Resolved https://github.com/ultralytics/ultralytics to commit c05d6d42616a3027faa687e1f272a53a5d7ed4d4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.3.80-py3-none-any.whl size=922098 sha256=38bf35a8539e9bf82f34a252038cdd122e62fae0884f1e6799f634b293c5c5e2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6d5_wlzk/wheels/a9/b9/3c/2bfed3b04e63cb4b7bb42f00b78184394b3d0a94897cb19f92
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.40
#     Uninstalling ultralytics-8.3.40:
#       Successfully uninstalled ultralytics-8.3.40
# ...

# %%
# !yolo export model=yolo11n.pt format=torchscript
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.00GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# TorchScript: export success ✅ 3.4s, saved as 'yolo11n.torchscript' (10.5 MB)
#
# Export complete (5.1s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolo11n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolo11n.torchscript imgsz=640 data=/usr/src/ultralytics/ultralytics/cfg/datasets/coco.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %%
# Git clone and run tests on updates branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 52701, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 52701 (delta 79), reused 52 (delta 50), pack-reused 52581 (from 2)
# Receiving objects: 100% (52701/52701), 29.65 MiB | 16.37 MiB/s, done.
# Resolving deltas: 100% (39065/39065), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
# !yolo val model=runs/detect/train/weights/best.pt data=/content/My-First-Project-1/data.yaml imgsz=640
# Out:
# Ultralytics 8.3.80 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/My-First-Project-1/valid/labels.cache... 133 images, 0 backgrounds, 0 corrupt: 100% 133/133 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:03<00:00,  3.00it/s]
#                    all        133        147      0.951      0.904      0.961      0.604
#                      0         27         37      0.945      0.784       0.94      0.557
#                      1         36         36      0.994          1      0.995      0.753
#                      2         27         27      0.887      0.889      0.929      0.554
#                      3         46         47      0.978      0.944      0.982      0.551
# Speed: 1.7ms preprocess, 7.5ms inference, 0.0ms loss, 3.3ms postprocess per image
# ...

# %%
# !yolo val model=/content/runs/detect/train/weights/best.pt data=/content/My-First-Project-1/data.yaml | grep "mAP50" | awk '{print "Model Accuracy: " int($6*100) "%"}'
# Out:
# val: Scanning /content/My-First-Project-1/valid/labels.cache... 133 images, 0 backgrounds, 0 corrupt: 100% 133/133 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  3.57it/s]

# %%
import re

# Sample YOLO validation log output
yolo_output = """
                   all        133        147      0.951      0.904      0.961      0.604
"""

# Extract mAP@50 value using regex
match = re.search(r"all\s+\d+\s+\d+\s+[\d.]+\s+[\d.]+\s+([\d.]+)", yolo_output)
if match:
    accuracy = float(match.group(1)) * 100
    print(f"🎯 Model Accuracy: {accuracy:.1f}%")
else:
    print("Accuracy not found in output.")
# Out:
# 🎯 Model Accuracy: 96.1%
