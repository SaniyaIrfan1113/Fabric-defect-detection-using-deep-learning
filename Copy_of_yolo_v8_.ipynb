# %% [markdown]
# <a href="https://colab.research.google.com/github/SaniyaIrfan1113/Fabric-defect-detection-using-deep-learning/blob/main/Copy_of_yolo_v8_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Feb  8 07:17:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.0/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Os3tZIQyYd0PrYzuaKzl")
project = rf.workspace("sanairfan").project("fdd-lmwhk-datwp-o7row")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to FDD-1 in yolov8:: 100%|██████████| 6726/6726 [00:02<00:00, 2649.59it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=50 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.3.73 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load an image from a file
img = mpimg.imread('/content/runs/detect/train2/results.png')

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load an image from a file
img = mpimg.imread('/content/runs/detect/train2/train_batch2.jpg')

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load an image from a file
img = mpimg.imread('/content/runs/detect/train2/F1_curve.png')

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load an image from a file
img = mpimg.imread('/content/runs/detect/train2/P_curve.png')

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load an image from a file
img = mpimg.imread('/content/runs/detect/train2/R_curve.png')

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load an image from a file
img = mpimg.imread('/content/runs/detect/train2/confusion_matrix.png')

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()
